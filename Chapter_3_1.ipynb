# %% [markdown]
# <a href="https://colab.research.google.com/github/mr1dwan/test1_sound-signal/blob/master/Chapter_3_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Out:
# --2020-10-02 09:45:09--  https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py [following]
# --2020-10-02 09:45:09--  https://raw.githubusercontent.com/AllenDowney/ThinkDSP/master/code/thinkdsp.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 48706 (48K) [text/plain]
# Saving to: ‘thinkdsp.py’
#
# thinkdsp.py         100%[===================>]  47.56K  --.-KB/s    in 0.02s
#
# 2020-10-02 09:45:09 (2.27 MB/s) - ‘thinkdsp.py’ saved [48706/48706]

# %%
# Get thinkdsp.py

import os

if not os.path.exists('thinkdsp.py'):
    # !wget https://github.com/AllenDowney/ThinkDSP/raw/master/code/thinkdsp.py

# %%
from thinkdsp import Chirp

signal = Chirp(start=220, end=880)
wave1 = signal.make_wave(duration=2)
wave1.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wave1.segment(start=0, duration=0.01).plot()
decorate(xlabel='Time (s)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f911259c3d0b> in <module>()
#       1 wave1.segment(start=0, duration=0.01).plot()
# ----> 2 decorate(xlabel='Time (s)')
#
# NameError: name 'decorate' is not defined

# %%
wave1.segment(start=0.9, duration=0.01).plot()
decorate(xlabel='Time (s)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e3cacd589766> in <module>()
#       1 wave1.segment(start=0.9, duration=0.01).plot()
# ----> 2 decorate(xlabel='Time (s)')
#
# NameError: name 'decorate' is not defined

# %%
from thinkdsp import ExpoChirp

signal = ExpoChirp(start=220, end=880)
wave2 = signal.make_wave(duration=2)
wave2.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from thinkdsp import SinSignal

signal = SinSignal(freq=440)

# %%
duration = signal.period * 30
wave = signal.make_wave(duration)
wave.plot()
decorate(xlabel='Time (s)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-72030b0988b2> in <module>()
#       2 wave = signal.make_wave(duration)
#       3 wave.plot()
# ----> 4 decorate(xlabel='Time (s)')
#
# NameError: name 'decorate' is not defined

# %%
spectrum = wave.make_spectrum()
spectrum.plot(high=880)
decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b6dde2c5067c> in <module>()
#       1 spectrum = wave.make_spectrum()
#       2 spectrum.plot(high=880)
# ----> 3 decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')
#
# NameError: name 'decorate' is not defined

# %%
duration = signal.period * 30.25
wave = signal.make_wave(duration)
wave.plot()
decorate(xlabel='Time (s)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-205b6f2ff7f1> in <module>()
#       2 wave = signal.make_wave(duration)
#       3 wave.plot()
# ----> 4 decorate(xlabel='Time (s)')
#
# NameError: name 'decorate' is not defined

# %%
spectrum = wave.make_spectrum()
spectrum.plot(high=880)
decorate(xlabel='Frequency (Hz)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-2f63a7ea852d> in <module>()
#       1 spectrum = wave.make_spectrum()
#       2 spectrum.plot(high=880)
# ----> 3 decorate(xlabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
wave.hamming()
spectrum = wave.make_spectrum()
spectrum.plot(high=880)
decorate(xlabel='Frequency (Hz)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9d4c7b38d48f> in <module>()
#       2 spectrum = wave.make_spectrum()
#       3 spectrum.plot(high=880)
# ----> 4 decorate(xlabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
signal = Chirp(start=220, end=440)
wave = signal.make_wave(duration=1)
spectrum = wave.make_spectrum()
spectrum.plot(high=700)
decorate(xlabel='Frequency (Hz)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-433beda76af5> in <module>()
#       3 spectrum = wave.make_spectrum()
#       4 spectrum.plot(high=700)
# ----> 5 decorate(xlabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
def plot_spectrogram(wave, seg_length):
    """
    """
    spectrogram = wave.make_spectrogram(seg_length)
    print('Time resolution (s)', spectrogram.time_res)
    print('Frequency resolution (Hz)', spectrogram.freq_res)
    spectrogram.plot(high=700)
    decorate(xlabel='Time(s)', ylabel='Frequency (Hz)')

# %%
signal = Chirp(start=220, end=440)
wave = signal.make_wave(duration=1, framerate=11025)
plot_spectrogram(wave, 512)
# Out:
# Time resolution (s) 0.046439909297052155
# Frequency resolution (Hz) 21.533203125
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-420a5877b531> in <module>()
#       1 signal = Chirp(start=220, end=440)
#       2 wave = signal.make_wave(duration=1, framerate=11025)
# ----> 3 plot_spectrogram(wave, 512)
#
# <ipython-input-14-f81141f1fae2> in plot_spectrogram(wave, seg_length)
#       6     print('Frequency resolution (Hz)', spectrogram.freq_res)
#       7     spectrogram.plot(high=700)
# ----> 8     decorate(xlabel='Time(s)', ylabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
plot_spectrogram(wave, 1024)
# Out:
# Time resolution (s) 0.09287981859410431
# Frequency resolution (Hz) 10.7666015625
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-37e10d2ed8f3> in <module>()
# ----> 1 plot_spectrogram(wave, 1024)
#
# <ipython-input-14-f81141f1fae2> in plot_spectrogram(wave, seg_length)
#       6     print('Frequency resolution (Hz)', spectrogram.freq_res)
#       7     spectrogram.plot(high=700)
# ----> 8     decorate(xlabel='Time(s)', ylabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
plot_spectrogram(wave, 256)
# Out:
# Time resolution (s) 0.023219954648526078
# Frequency resolution (Hz) 43.06640625
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-44b0d26c458b> in <module>()
# ----> 1 plot_spectrogram(wave, 256)
#
# <ipython-input-14-f81141f1fae2> in plot_spectrogram(wave, seg_length)
#       6     print('Frequency resolution (Hz)', spectrogram.freq_res)
#       7     spectrogram.plot(high=700)
# ----> 8     decorate(xlabel='Time(s)', ylabel='Frequency (Hz)')
#
# NameError: name 'decorate' is not defined

# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

slider = widgets.IntSlider(min=128, max=4096, value=100, step=128)
interact(plot_spectrogram, wave=fixed(wave), seg_length=slider);
# Out:
# interactive(children=(IntSlider(value=128, description='seg_length', max=4096, min=128, step=128), Output()), …

# %%
def eye_of_sauron(start, end):
    """Plots the spectrum of a chirp.
    
    start: initial frequency
    end: final frequency
    """
    signal =  Chirp(start=start, end=end)
    wave = signal.make_wave(duration=0.5)
    spectrum = wave.make_spectrum()
    
    spectrum.plot(high=1200)
    decorate(xlabel='Frequency (Hz)', ylabel='Amplitude')

# %%
slider1 = widgets.FloatSlider(min=100, max=1000, value=100, step=50)
slider2 = widgets.FloatSlider(min=100, max=1000, value=200, step=50)
interact(eye_of_sauron, start=slider1, end=slider2);
# Out:
# interactive(children=(FloatSlider(value=100.0, description='start', max=1000.0, min=100.0, step=50.0), FloatSl…
